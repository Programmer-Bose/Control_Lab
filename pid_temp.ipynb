# %% [markdown]
# ### Open Loop Study for Identification of Oven Parameters

# %%
import matplotlib.pyplot as plt
import numpy as np

#Time 
tim_i15 = np.array([15, 30, 45, 60, 75, 90, 105, 120, 135, 150, 165, 
                    180, 195, 210, 225, 240, 255, 270, 285, 300, 315, 
                    330, 345, 360, 375, 390, 405, 420, 435, 450, 465, 480, 
                    495, 510, 525, 540, 555, 570, 585, 600, 615, 630, 645, 
                    660, 675, 690, 705, 720, 735, 750, 765, 780, 795, 810, 
                    825, 840, 855, 870, 885, 900, 915, 930])

#Temp at 15 Sec Interval
temp = np.array([28.30, 31.50, 35.60, 40.40, 45.60, 51.80, 52.60, 60.70, 
                65.50, 68.70, 73.50, 77.20, 80.40, 83.70, 86.40, 89.00, 
                91.20, 93.40, 95.40, 97.10, 98.80, 100.30, 101.60, 102.90, 
                104.10, 105.20, 106.10, 107.20, 107.80, 108.60, 109.30, 
                109.90, 110.40, 110.90, 111.30, 111.70, 112.10, 112.50, 
                112.80, 113.10, 113.40, 114.1,114.5,114.9,115.2,115.6,116.2,
                116.4,116.7,116.9,117.1,117.2,117.3,117.5,117.6,117.8,118.00,
                118.1,118.2,118.4,118.5,118.6])

plt.grid(True)
# Plotting with markers
plt.plot(tim_i15, temp, marker='o', label='Temp')



# Adding labels and title
plt.xticks(range(0,1000,50))
plt.yticks(range(0,140,5))
plt.xlabel('Time (Sec)')
plt.ylabel('Temperature(degree C)')
plt.title('Open Loop Study for Identification of Oven Parameters')





# Adding a legend
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %% [markdown]
# ### Closed Loop Study of ON-OFF Controller with LOW Hysteresis
# #### Set Temp. = 55 deg C

# %%
import matplotlib.pyplot as plt
import numpy as np

#Time 
tim_i15 = np.array([15, 30, 45, 60, 75, 90, 105, 120, 135, 150, 165, 
                    180, 195, 210, 225, 240, 255, 270, 285, 300, 315, 
                    330, 345, 360, 375, 390, 405, 420])

#Temp at 15 Sec Interval
temp = np.array([27.80, 31.20, 35.60, 40.80, 46.10, 51.60, 56.80, 59.20,
                59.90, 59.60, 58.90, 57.60, 56.50, 55.20, 54.30, 55.30, 
                55.40, 54.80, 55.10, 55.20, 55.30, 55.60, 55.00, 54.90, 
                55.20, 54.70, 55.30, 55.10])

plt.grid(True)

# Plotting with markers
plt.plot(tim_i15, temp, marker='o', label='Temp')


# Adding labels and title
plt.xticks(range(0,500,50))
plt.yticks(range(25,60,5))
plt.xlabel('Time (Sec)')
plt.ylabel('Temperature(degree C)')
plt.title('Closed Loop Study of ON-OFF Controller with LOW Hysteresis (Set Temp. = 55 degree C)')



# Adding a legend
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %% [markdown]
# ### Closed Loop Study of Proportional Controller
# #### Set Temp. = 55 deg C

# %%
import matplotlib.pyplot as plt
import numpy as np

#Time 
tim_i15 = np.array([15, 30, 45, 60, 75, 90, 105, 120, 135, 150, 165, 
                    180, 195, 210, 225, 240, 255, 270, 285, 300, 315, 
                    330, 345, 360, 375, 390])

#Temp at 15 Sec Interval
temp = np.array([29.10, 32.40, 36.10, 42.50, 44.90, 49.10, 52.80, 54.90, 
                55.50, 55.20, 54.80, 54.00, 53.00, 52.30, 52.00, 52.00, 
                52.30, 52.60, 52.70, 52.80, 52.80, 52.70, 52.60, 52.60, 
                52.60, 52.60])

plt.grid(True)

# Plotting with markers
plt.plot(tim_i15, temp, marker='o', label='Temp')


# Adding labels and title
plt.xticks(range(0,450,50))
plt.yticks(range(25,60,5))
plt.xlabel('Time (Sec)')
plt.ylabel('Temperature(degree C)')
plt.title('Closed Loop Study of Proportional Controller (Set Temp. = 55 degree C)')



# Adding a legend
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %% [markdown]
# ### Closed Loop Study of Proportional-Integral  Controller
# #### **Set Temp. = 55 deg C**

# %%
import matplotlib.pyplot as plt
import numpy as np

#Time 
tim_i15 = np.array([15, 30, 45, 60, 75, 90, 105, 120, 135, 150, 165, 
                    180, 195, 210, 225, 240, 255, 270, 285, 300, 315, 
                    330, 345, 360, 375, 390, 405, 420, 435, 450, 465, 480])

#Temp at 15 Sec Interval
temp = np.array([27.60, 29.90, 32.60, 36.60, 41.70, 45.20, 49.30, 53.30, 56.20,
                57.60, 57.80, 57.40, 56.70, 55.70, 54.80, 54.20, 54.30, 54.60,
                55.20, 55.00, 54.80, 54.80, 54.90, 55.10, 55.00, 55.20, 55.30, 
                55.40, 55.60, 55.70, 55.50, 55.60])

plt.grid(True)
# Plotting with markers
plt.plot(tim_i15, temp, marker='o', label='Temp')



# Adding labels and title
plt.xticks(range(0,500,50))
plt.yticks(range(25,60,5))
plt.xlabel('Time (Sec)')
plt.ylabel('Temperature(degree C)')
plt.title('Closed Loop Study of Proportional-Integral  Controller (Set Temp. = 55 degree C)')





# Adding a legend
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %% [markdown]
# ### Closed Loop Study of Proportional-Integral-Derivative  Controller
# #### **Set Temp. = 55 deg C**

# %%
import matplotlib.pyplot as plt
import numpy as np

#Time 
tim_i15 = np.array([15, 30, 45, 60, 75, 90, 105, 120, 135, 150, 165, 
                    180, 195, 210, 225, 240, 255, 270, 285, 300, 315, 
                    330, 345, 360, 375, 390, 405, 420, 435, 450, 465, 480,495,510])

#Temp at 15 Sec Interval
temp = np.array([29.60, 32.70, 36.60, 41.20, 45.70, 50.10, 54.20, 57.60, 59.00, 59.30,
                58.80, 58.00, 56.90, 55.90, 55.50, 55.20, 55.50, 55.80, 56.00, 56.00,
                55.90, 55.80, 55.70, 55.60, 55.00, 55.20, 55.30, 55.40, 55.60, 55.70,
                55.50, 55.60, 55.40, 55.30])

plt.grid(True)
# Plotting with markers
plt.plot(tim_i15, temp, marker='o', label='Temp')



# Adding labels and title
plt.xticks(range(0,550,50))
plt.yticks(range(25,60,5))
plt.xlabel('Time (Sec)')
plt.ylabel('Temperature(degree C)')
plt.title('Closed Loop Study of Proportional-Integral-Derivative Controller (Set Temp. = 55 degree C)')





# Adding a legend
plt.legend(loc='upper right')

# Display the plot
plt.show()
