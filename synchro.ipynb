# %%
import matplotlib.pyplot as plt
import numpy as np

#Transmitter Stator Voltages
V_S12 = np.array([21.21, 12.726, 1.414, -7.07, -15.554, -25.452, -31.108, 
                 -35.35, -36.764, -35.35, -31.108, -24.038, -19.796, -8.484,
                 0, 7.07, 16.968, 24.038, 29.694, 35.35, 35.35, 35.35, 32.522,
                 26.866, 21.21])
V_S23 = np.array([-35.35, -35.35, -32.522, -26.866, -19.796, -11.312, -1.414,
                 7.07, 16.968, 16.968, 22.624, 29.694, 35.35, 36.764, 35.35,
                 31.108, 25.452, 18.382, 8.484, 0, -9.898, -16.968, -25.452,
                 -31.108, -33.936])
V_S13 = np.array([16.968, 26.866, 31.108, 35.35, 35.35, 33.936, 31.108, 26.866,
                 18.382, 9.898, 2.828, -7.07, -14.14, -22.624, -29.694, -33.936,
                 -38.178, -38.178, -35.35, -33.936, -28.28, -21.21, -11.312, 0,
                 9.898])

#Transmitter Rotor Position 
POS_DEG = np.array([0, 15, 30, 45, 60, 75, 90, 105, 120, 135, 150, 165, 180,
                   195, 210, 225, 240, 255, 270, 285, 300, 315, 330, 345, 360])

# Plotting with markers
plt.plot(POS_DEG, V_S12, marker='o', label='V_S12')
plt.plot(POS_DEG, V_S23, marker='s', label='V_S23')
plt.plot(POS_DEG, V_S13, marker='^', label='V_S13')

plt.grid(True)
# Adding labels and title
plt.xlabel('Transmitter Rotor Position')
plt.ylabel('Transmitter Stator Voltages')
plt.title('Transmitter Rotor Position vs Transmitter Stator Voltages')

#Adding Xlim & YLim
plt.xlim(0, 360)
plt.ylim(-40, 60)

# Adding a legend
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ERR_VP = np.array([0,2.5452,5.9388,9.0496,12.4432,12.726,13.433,12.4432,
                    9.7566,6.363,4.242,1.2726,-0.2828,-3.6764,-6.363,-9.191,
                    -12.1604,-13.8572,-12.726,-12.019,-9.898,-7.2114,-4.5248,
                    -2.5452,0])

POS_DEG = np.array([0, 15, 30, 45, 60, 75, 90, 105, 120, 135, 150, 165, 180,
                   195, 210, 225, 240, 255, 270, 285, 300, 315, 330, 345, 360])

# Plotting with markers
plt.plot(POS_DEG, ERR_VP, marker='o', label='ERR_VP')


plt.grid(True)
# Adding labels and title
plt.xlabel('Angular position(Degree)')
plt.ylabel('Error Voltage')
plt.title('Angular Position(Degree) vs Error Voltage')


# Adding a legend
plt.legend(loc='upper right')

# Display the plot
plt.show()
