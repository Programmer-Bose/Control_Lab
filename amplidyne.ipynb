# %% [markdown]
# ### No Load Charecteristics with Compensating Winding

# %%
import matplotlib.pyplot as plt
import numpy as np


i2_a = np.arange(0,12,1)
i2_b = np.arange(12,0,-1)

i1_a = np.arange(0,-12,-1)
i1_b = np.arange(-12,0,1)


i2a_v = np.array([-8.3,-6.9,-4.9,-1.9,-1.3,0.5,2.5,4.1,6.8,10.5,10.6,14.4])
i2b_v = np.array([14.5,13.0,9.8,7.5,5.4,3.1,1.8,-0.2,-1.4,-2.7,-4.9,-6.8])

i1a_v = np.array([-20.8,-29.5,-47.6,-61.3,-70.5,-76.6,-88.2,-98.1,-112.0,-121.5,
                 -124.0,-125.5])
i1b_v = np.array([-132.4,-129.5,-120.3,-114.2,-107.7,-92.8,-89.0,-79.9,-66.0,-55.4,
                 -42.1,-32.6])

hys_x = np.hstack((i2_a,i2_b,i1_a,i1_b))
hys_y = np.hstack((i2a_v,i2b_v,i1a_v,i1b_v))

# Plotting with markers
plt.plot(hys_x, hys_y, marker='.', label='VL(volts)')



plt.grid(True)
# Adding labels and title
plt.ylabel('VL in Volts')
plt.xlabel('<- (I1-I2) in mA (I2-I1) ->')
plt.title('No Load Charecteristics with Compensating Winding')

plt.ylim(-140,40)
# Adding a legend
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %% [markdown]
# ### Full Load Charecteristics with Compensating Winding

# %%
import matplotlib.pyplot as plt
import numpy as np


i2_a = np.arange(0,12,1)
i2_b = np.arange(12,0,-1)

i1_a = np.arange(0,-12,-1)
i1_b = np.arange(-12,0,1)


i2a_v = np.array([-15.3,-11.4,-15.1,-14.8,-13.1,-12.5,-9.0,-6.0,-3.7,-1.8,-0.7,0.1])
i2b_v = np.array([0.1,-0.4,-1.3,-2.8,-4.7,-7.1,-9.5,-11.4,-15.0,-16.8,-21.1,-23.0])

i1a_v = np.array([-23.1,-26.5,-36.5,-46.9,-55.8,-68.0,-72.5,-85.7,-91.6,-98.2,-101.8,-106.7])
i1b_v = np.array([-106.7,-98.5,-89.6,-92.3,-89.0,-82.3,-70.1,-66.5,-62.7,-55.6,-35.1,-24.5])

hys_x = np.hstack((i2_a,i2_b,i1_a,i1_b))
hys_y = np.hstack((i2a_v,i2b_v,i1a_v,i1b_v))

# Plotting with markers
plt.plot(hys_x, hys_y, marker='.', label='VL(volts)')



plt.grid(True)
# Adding labels and title
plt.ylabel('VL in Volts')
plt.xlabel('<- (I1-I2) in mA (I2-I1) ->')
plt.title('Full Load Charecteristics with Compensating Winding')

plt.ylim(-140,40)
# Adding a legend
plt.legend(loc='upper right')

# Display the plot
plt.show()

# %% [markdown]
# ### Full Load Charecteristics without Compensating Winding

# %%
import matplotlib.pyplot as plt
import numpy as np


i2_a = np.arange(0,12,1)
i2_b = np.arange(12,0,-1)

i1_a = np.arange(0,-12,-1)
i1_b = np.arange(-12,0,1)


i2a_v = np.array([-0.8,-0.7,-0.6,-0.5,-0.6,-0.7,-0.6,-0.7,-0.6,-0.5,-0.5,-0.4])
i2b_v = np.array([-0.4,-0.1,-0.1,-0.2,-0.5,-0.6,-0.6,-0.7,-0.7,-0.7,-0.8,-0.8])

i1a_v = np.array([-0.8,-0.9,-1.3,-1.7,-2.0,-2.5,-3.1,-3.3,-3.4,-3.8,-4.5,-6.2])
i1b_v = np.array([-5.0,-5.3,-4.8,-4.1,-3.2,-3.0,-2.6,-2.0,-1.7,-1.5,-1.1,-0.8])

hys_x = np.hstack((i2_a,i2_b,i1_a,i1_b))
hys_y = np.hstack((i2a_v,i2b_v,i1a_v,i1b_v))

# Plotting with markers
plt.plot(hys_x, hys_y, marker='.', label='VL(volts)')



plt.grid(True)
# Adding labels and title
plt.ylabel('VL in Volts')
plt.xlabel('<- (I1-I2) in mA (I2-I1) ->')
plt.title('Full Load Charecteristics without Compensating Winding')

plt.ylim(-7,1)
# Adding a legend
plt.legend(loc='upper right')

# Display the plot
plt.show()
